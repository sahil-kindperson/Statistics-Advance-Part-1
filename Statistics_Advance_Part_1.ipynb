# %%
### THEORITICAL QUESTIONS

# %%
#1. What is a random variable in probability theory?

# %% [markdown]
# In probability theory, a random variable is a function that assigns a numerical value to each outcome in a sample space of a random experiment.

# %%
#2. What are the types of random variables?

# %% [markdown]
# 1. Discrete Random Variables
# 2. Continuous Random Variables

# %%
#3. What is the difference between discrete and continuous distributions?

# %% [markdown]
# 1. Discrete Distributions
# A discrete distribution is associated with a discrete random variable, which takes on countable values (finite or countably infinite).
#
# Probabilities are assigned to specific values using a Probability Mass Function (PMF).
#
# The sum of probabilities for all possible values must equal 1.
#
#
# 2. Continuous Distributions
# A continuous distribution is associated with a continuous random variable, which takes on uncountable values (typically real numbers over an interval).
#
# Probabilities are assigned over an interval using a Probability Density Function (PDF).
#
# The probability of any exact value is zero, i.e.,
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 0
# P(X=x)=0. Instead, probability is given by the area under the PDF curve over a range.

# %%
#4. What are probability distribution functions (PDF)?

# %% [markdown]
# In probability theory, a Probability Distribution Function (PDF) describes the likelihood of a continuous random variable taking on a certain value within a range.

# %%
#5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?

# %% [markdown]
# *   PDF tells you how dense the probability is at a point.
#
# *   CDF tells you how much probability has accumulated up to that point.

# %%
#6. What is a discrete uniform distribution?

# %% [markdown]
# A discrete uniform distribution is one of the simplest types of probability distributions. It describes a situation where a finite number of outcomes are all equally likely.

# %%
#7. What are the key properties of a Bernoulli distribution?

# %% [markdown]
# **Bernoulli Distribution: Key Properties**
#
# A Bernoulli distribution is a discrete probability distribution that models a single experiment with two possible outcomes:
#
#
# *   Success (
# 𝑋
# =
# 1
# X=1) with probability
# 𝑝
# p
# *   Failure (
# 𝑋
# =
# 0
# X=0) with probability
# 1
# −
# 𝑝
# 1−p

# %%
#8. What is the binomial distribution, and how is it used in probability?

# %% [markdown]
# The binomial distribution models the number of successes in a fixed number of independent Bernoulli trials, where each trial has only two possible outcomes:
#
# Success (with probability
# 𝑝
# p)
#
# Failure (with probability
# 1
# −
# 𝑝
# 1−p)

# %%
#9. What is the Poisson distribution and where is it applied?

# %% [markdown]
# The Poisson distribution models the probability of a given number of events occurring in a fixed interval of time or space, assuming the events happen randomly, independently, and at a constant average rate.
#
# It is applied in:
# 1. Queueing & Service Systems
# 2. Telecommunications & Traffic
# 3. Healthcare & Biology
# 4. Business & Economics

# %%
#10. What is a continuous uniform distribution?

# %% [markdown]
# The continuous uniform distribution describes a random variable that has an equal probability of occurring anywhere within a given range
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b]. It is often called a rectangular distribution because its probability density function (PDF) is a flat, constant line.

# %%
#11. What are the characteristics of a normal distribution?

# %% [markdown]
# The normal distribution, also called the Gaussian distribution, is a continuous probability distribution that is symmetric and bell-shaped. It is one of the most important distributions in probability and statistics because many natural and real-world phenomena follow it.

# %%
#12. What is the standard normal distribution, and why is it important?

# %% [markdown]
# The standard normal distribution is a special case of the normal distribution where:
#
#
# *   The mean (
# 𝜇
# μ) is 0
# *   The standard deviation (
# 𝜎
# σ) is 1

# %%
#13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?

# %% [markdown]
# The Central Limit Theorem (CLT) states that the sampling distribution of the sample mean (or sum) of a sufficiently large sample from any population—regardless of its original distribution—will be approximately normal.
#
# Why is the CLT Critical in Statistics?
#
# 1. Justifies the Use of Normal Distribution
# 2. Essential for Confidence Intervals & Hypothesis Testing
# 3. Used in Practical Applications

# %%
#`14. How does the Central Limit Theorem relate to the normal distribution?

# %% [markdown]
# The Central Limit Theorem (CLT) explains why the normal distribution is so commonly observed in statistics. It states that when we take a large enough sample size (
# 𝑛
# n) from any population (regardless of its original distribution), the sampling distribution of the sample mean will approximate a normal distribution.
#
# This means that even if the original population is skewed, uniform, or multimodal, the sample means will still follow a normal distribution as
# 𝑛
# n increases.

# %%
#15. What is the application of Z statistics in hypothesis testing?

# %% [markdown]
# Z-statistics (or Z-tests) are used in hypothesis testing when the population variance (
# 𝜎
# 2
# σ
# 2
#  ) is known or when the sample size is large (
# 𝑛
# ≥
# 30
# n≥30). It allows us to determine whether a sample mean significantly differs from a population mean.

# %%
#16. How do you calculate a Z-score, and what does it represent?

# %% [markdown]
# The Z-score is calculated as:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
#
#
#
# The Z-Score Represents:
#
# *   Z=0 → The data point is exactly at the mean.
#
#
#
# *   Z>0 → The data point is above the mean (higher than average).
# *   Z<0 → The data point is below the mean (lower than average).
#
#
# *   ∣
# 𝑍
# ∣
# >
# 2
# ∣Z∣>2 → The data point is unusual (more than 2 standard deviations from the mean).
#
# *   ∣Z∣>3 → The data point is extremely rare in a normal distribution (~0.3% probability).

# %%
#17. What are point estimates and interval estimates in statistics?

# %% [markdown]
# In inferential statistics, we often estimate unknown population parameters (like the mean
# 𝜇
# μ or proportion
# 𝑝
# p) using sample data. The two main types of estimates are:
#
# Point Estimates → A single best guess of a population parameter.
#
# Interval Estimates → A range of values (confidence interval) where the parameter is likely to fall.

# %%
#18. What is the significance of confidence intervals in statistical analysis?

# %% [markdown]
# A confidence interval (CI) is a range of values that is likely to contain the true population parameter with a certain level of confidence (e.g., 90%, 95%, 99%). It helps measure uncertainty and reliability in statistical estimates.

# %%
#19. What is the relationship between a Z-score and a confidence interval?

# %% [markdown]
# A Z-score and a confidence interval (CI) are closely related because Z-scores determine how far a data point (or an estimate) is from the mean in terms of standard deviations. In the context of confidence intervals, Z-scores are used to calculate the margin of error, which defines the range of the interval.

# %%
#20. How are Z-scores used to compare different distributions?

# %% [markdown]
# A Z-score (standard score) measures how far a data point is from the mean of its distribution in terms of standard deviations. This allows comparisons between values from different distributions, even if they have different means and standard deviations.

# %%
#21. What are the assumptions for applying the Central Limit Theorem?

# %% [markdown]
# The Central Limit Theorem (CLT) states that the sampling distribution of the sample mean (or sum) approaches a normal distribution as the sample size increases, regardless of the shape of the population distribution.
#
# To apply the CLT correctly, certain assumptions must be met:
#
# 1. Random Sampling
# 2. Independence of Observations
# 3. Sample Size Should Be Large Enough

# %%
#22. What is the concept of expected value in a probability distribution?

# %% [markdown]
# The expected value (EV) of a random variable represents the long-term average or mean of possible outcomes in a probability distribution. It gives an idea of what to expect over many trials.

# %%
#23. How does a probability distribution relate to the expected outcome of a random variable

# %% [markdown]
# A probability distribution describes how likely different values of a random variable are to occur. The expected value (or mean) of the random variable represents the long-term average outcome of repeated trials based on this distribution.

# %%
###PRACTICAL QUESTIONS

# %%
#1. Write a Python program to generate a random variable and display its value.

import random


random_variable = random.randint(1, 6)

print("Random variable (die roll):", random_variable)
# Out:
# Random variable (die roll): 6

# %%
#2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF)


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define range of the discrete uniform distribution
low = 1       # inclusive
high = 7      # exclusive (so 1 to 6 for a fair die)

# Create a discrete uniform distribution object
dist = randint(low, high)

# Possible outcomes
x = np.arange(low, high)

# PMF values
pmf = dist.pmf(x)

# %%
#3. Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution.

def bernoulli_pdf(x, p):
    """
    Compute the PDF of a Bernoulli distribution.

    Parameters:
    - x (int): The outcome (0 or 1)
    - p (float): Probability of success (0 <= p <= 1)

    Returns:
    - float: Probability of observing outcome x
    """
    if x == 1:
        return p
    elif x == 0:
        return 1 - p
    else:
        return 0.0



p = 0.7


print("P(X=1):", bernoulli_pdf(1, p))
print("P(X=0):", bernoulli_pdf(0, p))
# Out:
# P(X=1): 0.7
# P(X=0): 0.30000000000000004

# %%
#4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n = 10
p = 0.5
size = 10000

samples = np.random.binomial(n, p, size)

plt.figure(figsize=(8, 5))
plt.hist(samples, bins=range(n+2), align='left', rwidth=0.8, color='skyblue', edgecolor='black', density=True)

x = np.arange(0, n+1)
pmf = binom.pmf(x, n, p)
plt.plot(x, pmf, 'o-', color='darkblue', label='Theoretical PMF')


plt.title(f'Binomial Distribution (n={n}, p={p})', fontsize=14)
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#5.  Create a Poisson distribution and visualize it using Python.


lambda_val = 4

# Define range of possible values
x = np.arange(0, 15)

# Calculate PMF values
pmf = poisson.pmf(x, mu=lambda_val)

# %%
#6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution
import matplotlib.pyplot as plt
from scipy.stats import randint

low = 1
high = 7


dist = randint(low, high)


x = np.arange(low, high)

cdf = dist.cdf(x)


plt.figure(figsize=(8, 5))
plt.step(x, cdf, where='post', color='blue', label='CDF')
plt.title('CDF of Discrete Uniform Distribution (Fair Die)', fontsize=14)
plt.xlabel('Outcome')
plt.ylabel('Cumulative Probability')
plt.xticks(x)
plt.grid(True, linestyle='--', alpha=0.6)
plt.ylim(0, 1.1)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#7. Generate a continuous uniform distribution using NumPy and visualize it.


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

a = 0
b = 1
size = 10000

samples = np.random.uniform(a, b, size)

plt.figure(figsize=(8, 5))
count, bins, ignored = plt.hist(samples, bins=50, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Sampled Data')


x = np.linspace(a, b, 1000)
pdf = uniform.pdf(x, loc=a, scale=b-a)
plt.plot(x, pdf, 'r-', lw=2, label='Theoretical PDF')

plt.title(f'Continuous Uniform Distribution U({a}, {b})', fontsize=14)
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#8.  Simulate data from a normal distribution and plot its histogram.



import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Parameters for the normal distribution
mean = 0       # μ (mu) - the mean
std_dev = 1    # σ (sigma) - the standard deviation
size = 10000   # Number of random samples


samples = np.random.normal(mean, std_dev, size)


plt.figure(figsize=(8, 5))
count, bins, _ = plt.hist(samples, bins=50, density=True, alpha=0.6, color='lightblue', edgecolor='black', label='Sampled Data')


x = np.linspace(min(bins), max(bins), 1000)
pdf = norm.pdf(x, mean, std_dev)
plt.plot(x, pdf, 'r-', lw=2, label='Theoretical PDF')

plt.title(f'Normal Distribution (μ = {mean}, σ = {std_dev})', fontsize=14)
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#9. Write a Python function to calculate Z-scores from a dataset and plot them.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_and_plot_z_scores(data):
    """
    Calculate Z-scores from a dataset and plot a histogram with standard normal curve.

    Parameters:
    - data (array-like): Input dataset (numeric values)
    """
    data = np.array(data)
    mean = np.mean(data)
    std = np.std(data)

    z_scores = (data - mean) / std

    plt.figure(figsize=(8, 5))
    count, bins, _ = plt.hist(z_scores, bins=50, density=True, alpha=0.6, color='lightcoral', edgecolor='black', label='Z-score Histogram')

    x = np.linspace(-4, 4, 1000)
    pdf = norm.pdf(x, 0, 1)
    plt.plot(x, pdf, 'b-', lw=2, label='Standard Normal PDF')

    plt.title('Z-score Distribution with Standard Normal Overlay', fontsize=14)
    plt.xlabel('Z-score')
    plt.ylabel('Density')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()
    plt.tight_layout()
    plt.show()

    return z_scores


# Simulate some data
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

# Calculate and plot Z-scores
z_scores = calculate_and_plot_z_scores(data)

# %%
#10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

population_size = 100000
sample_size = 50
num_samples = 1000
lambda_val = 1.0

population = np.random.exponential(scale=1/lambda_val, size=population_size)

sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

plt.figure(figsize=(8, 5))
plt.hist(sample_means, bins=40, density=True, alpha=0.6, color='skyblue', edgecolor='black', label='Sample Means')

mean_of_means = np.mean(sample_means)
std_of_means = np.std(sample_means)
x = np.linspace(mean_of_means - 4*std_of_means, mean_of_means + 4*std_of_means, 1000)
plt.plot(x, norm.pdf(x, mean_of_means, std_of_means), 'r-', lw=2, label='Normal PDF')

plt.title(f'Central Limit Theorem Demonstration\nSample Size = {sample_size}, Num Samples = {num_samples}', fontsize=13)
plt.xlabel('Sample Mean')
plt.ylabel('Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#11. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Step 1: Define population parameters
population_mean = 100
population_std = 15
population_size = 100000

# Generate a normal population
population = np.random.normal(loc=population_mean, scale=population_std, size=population_size)

# Step 2: Sampling parameters
sample_size = 50
num_samples = 1000

# Step 3: Collect multiple sample means
sample_means = []
for _ in range(num_samples):
    sample = np.random.choice(population, size=sample_size, replace=False)
    sample_means.append(np.mean(sample))

# Step 4: Plot the histogram of sample means
plt.figure(figsize=(8, 5))
plt.hist(sample_means, bins=40, density=True, alpha=0.7, color='lightgreen', edgecolor='black', label='Sample Means')

# Overlay the theoretical normal curve
mean_of_means = np.mean(sample_means)
std_of_means = np.std(sample_means)
x = np.linspace(mean_of_means - 4*std_of_means, mean_of_means + 4*std_of_means, 1000)
plt.plot(x, norm.pdf(x,))

# %%
#12. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Plot the standard normal distribution (mean = 0, std = 1).
    """
    x = np.linspace(-4, 4, 1000)

    pdf = norm.pdf(x, loc=0, scale=1)

    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf, color='darkblue', lw=2, label='Standard Normal PDF')
    plt.fill_between(x, pdf, alpha=0.2, color='blue')

    plt.title('Standard Normal Distribution (μ = 0, σ = 1)', fontsize=14)
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.axvline(0, color='gray', linestyle='--', linewidth=1)
    plt.legend()
    plt.tight_layout()
    plt.show()

plot_standard_normal_distribution()

# %%
#13. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

import numpy as np
from scipy.stats import binom
import matplotlib.pyplot as plt

# Parameters
n = 10        # number of trials
p = 0.5       # probability of success
size = 10     # number of random variables to generate

# Generate random variables from Binomial(n, p)
random_values = np.random.binomial(n, p, size)

# Calculate corresponding probabilities (PMF)
pmf_values = binom.pmf(random_values, n, p)

# Print results
print("Random Binomial Values and their Probabilities:")
for rv, prob in zip(random_values, pmf_values):
    print(f"Value: {rv}, Probability: {prob:.4f}")

# Optional: Plot the PMF for all possible outcomes
x = np.arange(0, n+1)
pmf_all = binom.pmf(x, n, p)
# Out:
# Random Binomial Values and their Probabilities:
# Value: 4, Probability: 0.2051
# Value: 4, Probability: 0.2051
# Value: 10, Probability: 0.0010
# Value: 5, Probability: 0.2461
# Value: 4, Probability: 0.2051
# Value: 6, Probability: 0.2051
# Value: 4, Probability: 0.2051
# Value: 6, Probability: 0.2051
# Value: 1, Probability: 0.0098
# Value: 5, Probability: 0.2461

# %%
#14. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(x, mean, std_dev):
    """
    Calculate Z-score for a given data point.
    """
    return (x - mean) / std_dev

def plot_z_score(z):
    """
    Plot the standard normal distribution and mark the Z-score.
    """
    x_vals = np.linspace(-4, 4, 1000)
    y_vals = norm.pdf(x_vals, 0, 1)

    plt.figure(figsize=(8, 5))
    plt.plot(x_vals, y_vals, label='Standard Normal PDF', color='navy')
    plt.fill_between(x_vals, y_vals, where=(x_vals <= z), color='lightcoral', alpha=0.5, label=f'Area ≤ Z = {z:.2f}')
    plt.axvline(z, color='red', linestyle='--', label=f'Z = {z:.2f}')

    plt.title('Z-score in Standard Normal Distribution', fontsize=14)
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.legend()
    plt.tight_layout()
    plt.show()

x = 85
mean = 70
std_dev = 10

z_score = calculate_z_score(x, mean, std_dev)
print(f"Z-score for x = {x} (mean = {mean}, std = {std_dev}): {z_score:.2f}")

plot_z_score(z_score)
# Out:
# Z-score for x = 85 (mean = 70, std = 10): 1.50

# %%
#14. Implement hypothesis testing using Z-statistics for a sample dataset.

import numpy as np
from scipy.stats import norm

def z_test_one_sample(sample_data, population_mean, population_std, alpha=0.05):
    # Calculate sample statistics
    sample_mean = np.mean(sample_data)
    sample_size = len(sample_data)

    z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))

    p_value = 2 * (1 - norm.cdf(abs(z_stat)))

    print(f"Sample Mean      = {sample_mean:.2f}")
    print(f"Z-Statistic      = {z_stat:.4f}")
    print(f"P-value          = {p_value:.4f}")
    print(f"Significance α   = {alpha}")

    if p_value < alpha:
        print("Result: Reject the null hypothesis (H₀)")
    else:
        print("Result: Fail to reject the null hypothesis (H₀)")

sample = [102, 98, 101, 105, 100, 97, 99, 103, 96, 104]
z_test_one_sample(sample, population_mean=100, population_std=15, alpha=0.05)
# Out:
# Sample Mean      = 100.50
# Z-Statistic      = 0.1054
# P-value          = 0.9161
# Significance α   = 0.05
# Result: Fail to reject the null hypothesis (H₀)

# %%
#15. Create a confidence interval for a dataset using Python and interpret the result.

import numpy as np
from scipy import stats

def confidence_interval(data, confidence=0.95):
    n = len(data)
    mean = np.mean(data)
    std_err = stats.sem(data)

    t_crit = stats.t.ppf((1 + confidence) / 2, df=n-1)

    margin_of_error = t_crit * std_err

    lower = mean - margin_of_error
    upper = mean + margin_of_error

    print(f"Sample Mean        = {mean:.2f}")
    print(f"{int(confidence*100)}% Confidence Interval = ({lower:.2f}, {upper:.2f})")
    print("\nInterpretation:")
    print(f"We are {int(confidence*100)}% confident that the true population mean lies between {lower:.2f} and {upper:.2f}.")

sample_data = [102, 98, 101, 105, 100, 97, 99, 103, 96, 104]
confidence_interval(sample_data, confidence=0.95)
# Out:
# Sample Mean        = 100.50
# 95% Confidence Interval = (98.33, 102.67)
#
# Interpretation:
# We are 95% confident that the true population mean lies between 98.33 and 102.67.

# %%
#16. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# Step 1: Generate data from a normal distribution
np.random.seed(42)  # for reproducibility
mu = 70       # true population mean
sigma = 10    # population standard deviation
n = 30        # sample size

sample_data = np.random.normal(loc=mu, scale=sigma, size=n)

# Step 2: Calculate confidence interval for the sample mean
sample_mean = np.mean(sample_data)
sample_se = stats.sem(sample_data)  # standard error of the mean
confidence = 0.95

# t-critical value for two-tailed test
t_crit = stats.t.ppf((1 + confidence) / 2, df=n-1)

# Margin of error
margin_of_error = t_crit * sample_se

# Confidence interval bounds
ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

# Step 3: Print results
print(f"Sample Mean = {sample_mean:.2f}")
print(f"95% Confidence Interval = ({ci_lower:.2f}, {ci_upper:.2f})")
print(f"\nInterpretation: We are 95% confident that the true population mean lies between {ci_lower:.2f} and {ci_upper:.2f}.")

# Step 4: Optional – plot the data and CI
plt.figure(figsize=(8, 4))
plt.errorbar(1, sample_mean, yerr=margin_of_error, fmt='o', capsize=5, color='darkblue')
plt.axhline(mu, color='green', linestyle='--', label=f'True Mean = {mu}')
plt.title('95% Confidence Interval for the Mean')
plt.ylabel('Value')
plt.xticks([])
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()
# Out:
# Sample Mean = 68.12
# 95% Confidence Interval = (64.76, 71.48)
#
# Interpretation: We are 95% confident that the true population mean lies between 64.76 and 71.48.

# %%
#17. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

mean = 0
std_dev = 1

x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, 1000)

pdf = norm.pdf(x, mean, std_dev)

plt.figure(figsize=(8, 5))
plt.plot(x, pdf, color='darkblue', lw=2, label=f'N(μ={mean}, σ={std_dev})')
plt.title('Probability Density Function (PDF) of a Normal Distribution')
plt.xlabel('x')
plt.ylabel('Probability Density')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()

# %%
#18. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Set Poisson distribution parameter (average rate of events)
lambda_val = 4  # average number of events

# Generate x values (number of events)
x = np.arange(0, 15)

# Calculate CDF values
cdf = poisson.cdf(x, mu=lambda_val)

# Print a few example values
for i in range(len(x)):
    print(f"P(X ≤ {x[i]}) = {cdf[i]:.4f}")

# Plot the CDF
plt.figure(figsize=(8, 5))
plt.step(x, cdf, where='post', label=f'Poisson CDF (λ = {lambda_val})', color='purple')
plt.title('CDF of a Poisson Distribution')
plt.xlabel('Number of Events (k)')
plt.ylabel('P(X ≤ k)')
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# P(X ≤ 0) = 0.0183
# P(X ≤ 1) = 0.0916
# P(X ≤ 2) = 0.2381
# P(X ≤ 3) = 0.4335
# P(X ≤ 4) = 0.6288
# P(X ≤ 5) = 0.7851
# P(X ≤ 6) = 0.8893
# P(X ≤ 7) = 0.9489
# P(X ≤ 8) = 0.9786
# P(X ≤ 9) = 0.9919
# P(X ≤ 10) = 0.9972
# P(X ≤ 11) = 0.9991
# P(X ≤ 12) = 0.9997
# P(X ≤ 13) = 0.9999
# P(X ≤ 14) = 1.0000

# %%
#19. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

import numpy as np

# Set the range for the uniform distribution
a = 10
b = 30
n_samples = 10000

# Simulate random variables from the uniform distribution
samples = np.random.uniform(low=a, high=b, size=n_samples)

# Calculate theoretical and empirical expected value
theoretical_mean = (a + b) / 2
empirical_mean = np.mean(samples)

# Print results
print(f"Range: [{a}, {b}]")
print(f"Theoretical Expected Value: {theoretical_mean:.2f}")
print(f"Empirical Mean from Simulation: {empirical_mean:.2f}")
# Out:
# Range: [10, 30]
# Theoretical Expected Value: 20.00
# Empirical Mean from Simulation: 19.89

# %%
#20. Write a Python program to compare the standard deviations of two datasets and visualize the difference

import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate two datasets
np.random.seed(42)
data1 = np.random.normal(loc=50, scale=5, size=1000)   # Smaller spread
data2 = np.random.normal(loc=50, scale=15, size=1000)  # Larger spread

# Step 2: Calculate standard deviations
std1 = np.std(data1, ddof=1)
std2 = np.std(data2, ddof=1)

print(f"Standard Deviation of Dataset 1: {std1:.2f}")
print(f"Standard Deviation of Dataset 2: {std2:.2f}")

# Step 3: Visualize using a bar chart
plt.figure(figsize=(10, 4))

# Bar chart comparison
plt.subplot(1, 2, 1)
plt.bar(['Dataset 1', 'Dataset 2'], [std1, std2], color=['skyblue', 'salmon'])
plt.title('Standard Deviation Comparison')
plt.ylabel('Standard Deviation')

# Step 4: Visualize using histograms
plt.subplot(1, 2, 2)
plt.hist(data1, bins=30, alpha=0.6, label='Dataset 1 (σ ≈ 5)', color='skyblue')
plt.hist(data2, bins=30, alpha=0.6, label='Dataset 2 (σ ≈ 15)', color='salmon')
plt.title('Distribution of Two Datasets')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Standard Deviation of Dataset 1: 4.90
# Standard Deviation of Dataset 2: 14.96

# %%
#21. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution

import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate data from a normal distribution
np.random.seed(42)
data = np.random.normal(loc=50, scale=10, size=1000)

# Step 2: Calculate Range
data_range = np.max(data) - np.min(data)

# Step 3: Calculate IQR (Interquartile Range)
q1 = np.percentile(data, 25)
q3 = np.percentile(data, 75)
iqr = q3 - q1

# Step 4: Print results
print(f"Range: {data_range:.2f}")
print(f"Q1 (25th percentile): {q1:.2f}")
print(f"Q3 (75th percentile): {q3:.2f}")
print(f"Interquartile Range (IQR): {iqr:.2f}")

# Step 5: Optional - Visualize with a boxplot
plt.boxplot(data, vert=False)
plt.title('Boxplot of Normally Distributed Data')
plt.xlabel('Value')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
# Out:
# Range: 70.94
# Q1 (25th percentile): 43.52
# Q3 (75th percentile): 56.48
# Interquartile Range (IQR): 12.96

# %%
#22. Implement Z-score normalization on a dataset and visualize its transformation

import numpy as np
import matplotlib.pyplot as plt

# Step 1: Generate a synthetic dataset (e.g., normal distribution)
np.random.seed(42)
data = np.random.normal(loc=60, scale=15, size=1000)

# Step 2: Z-score normalization
mean = np.mean(data)
std = np.std(data)
z_scores = (data - mean) / std

# Step 3: Print summary
print(f"Original Mean: {mean:.2f}, Original Std Dev: {std:.2f}")
print(f"Z-Score Mean: {np.mean(z_scores):.2f}, Z-Score Std Dev: {np.std(z_scores):.2f}")

# Step 4: Visualize original and normalized data
plt.figure(figsize=(12, 5))

# Original Data Histogram
plt.subplot(1, 2, 1)
plt.hist(data, bins=30, color='skyblue', edgecolor='black')
plt.title('Original Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')

# Z-Score Normalized Histogram
plt.subplot(1, 2, 2)
plt.hist(z_scores, bins=30, color='salmon', edgecolor='black')
plt.title('Z-Score Normalized Distribution')
plt.xlabel('Z-score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()
# Out:
# Original Mean: 60.29, Original Std Dev: 14.68
# Z-Score Mean: 0.00, Z-Score Std Dev: 1.00

# %%
#23. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.


import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis

def analyze_normal_distribution_skew_kurtosis(mean=0, std_dev=1, size=1000, visualize=True):
    # Generate data from a normal distribution
    data = np.random.normal(loc=mean, scale=std_dev, size=size)

    # Calculate skewness and kurtosis
    skewness = skew(data)
    excess_kurtosis = kurtosis(data)  # By default, returns excess kurtosis (kurtosis - 3)

    print(f"Skewness: {skewness:.4f}")
    print(f"Kurtosis (Excess): {excess_kurtosis:.4f}")
    print(f"Kurtosis (Actual): {excess_kurtosis + 3:.4f}")

    # Optional: plot histogram
    if visualize:
        plt.hist(data, bins=30, edgecolor='black', color='skyblue', alpha=0.7)
        plt.title("Histogram of Normally Distributed Data")
        plt.xlabel("Value")
        plt.ylabel("Frequency")
        plt.grid(True, linestyle='--', alpha=0.6)
        plt.tight_layout()
        plt.show()

    return skewness, excess_kurtosis

# Example usage
analyze_normal_distribution_skew_kurtosis()
# Out:
# Skewness: -0.0493
# Kurtosis (Excess): 0.0521
# Kurtosis (Actual): 3.0521
# (np.float64(-0.049321773965299257), np.float64(0.05211754569784022))
